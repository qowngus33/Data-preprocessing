# %% [markdown]
# <a href="https://colab.research.google.com/github/qowngus33/Open-Potal-preprocessing/blob/main/sympton_list.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %matplotlib inline

import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

import pandas as pd

# 데이터프레임을 읽어옴
petDisease = pd.read_csv('pet.csv',encoding='cp949')

# %%
# 데이터프레임 출력
petDisease
# Out:
#         번호                                                질병명      축종  \
# 0        1                           갑상선기능저하증(Hypothyroidism)  개, 고양이
# 1        2                         갑상선기능항진증 (Hyperthyroidism)  개, 고양이
# 2        3      코로나 바이러스 감염증, 개(Canine Coronavirus Infection)       개
# 3        4         파보바이러스 감염증, 개(Canine Parvoviral Infection)       개
# 4        5                  디스템퍼(Canine Distemper:CD), 개, 개홍역       개
# ...    ...                                                ...     ...
# 1523  1534  데본 렉스 종 고양이에서 발생하는 비타민 K 의존성 다인성 응고 부전 (Vitami...     고양이
# 1524  1535  개에서의 기관 내 삽관 후 발생하는 성대 마비 (Vocal cord paralysi...       개
# 1525  1536  도베르만 핀셔에서의 폰 빌리브란트 이소성 osteochondrofibrosis (V...       개
# 1526  1537               폰 빌리브란트 병 (Von willebrand's disease)  개, 고양이
# 1527  1538  개와 고양이의 외음부와 질의 종양 (Vulval and vaginal neoplas...  개, 고양이
#
#                                                      정의  \
# 0     갑상선에서 T3, T4의 부적절한 생산, 분비로 세포대사활성 및 행동기능의 저하가 ...
# 1                    T3와 T4의 분비와 과도한 생산물에 결과로 나타난 질병 \r
# 2     개 코로나 바이러스(CCV)에 의해 발생하며 구토와 설사를 수반하는 장염을 유발하는...
# 3              주로 3주미만의 어린 개에서 출혈성 장염을 일으키는 급성 위장관 질환\r
# 4     급성, 아급성 전염성 열성 질환으로 3-6개월령에 다발, 전신형, 호흡기, 소화기,...
# ...                                                 ...
# 1523  응고인자 II, VII, IX, X을 비타민 K 의존성 응고 단백질이라고 한다. 데...
# 1524  기관 내 삽관 방식으로 마취를 한 후에 개가 더 이상 짖지 못하게 될 수 있다. 사...
# 1525  암컷 도베르만 핀셔의 엉덩이 주위에서 뼈, 연골, 결합조직 또는 이들 조직이 혼합되...
# 1526   빌리브란트 병은 정상적인 혈소판 부착에 필수적인 폰 빌리브란트 인자의 양적, 질적...
# 1527  전파성 성기 육종을 제외하고는 질의 종양은 드물게 발생한다. 폴립을 포함하여 양성 ...
#
#                                                      원인  \
# 0     #후천성 갑상선기능저하증\r#림프구성 갑상선염(lymphocytic thyrodit...
# 1     세포의 과증식인지 종양발생이 원인인지는 불분명하나 음식의 변화, 편식,    환경오...
# 2                                   canine coronavirus
# 3                         Canine Parvovirus 2(CPV-2)\r
# 4                        canine distemper virus(CDV) \r
# ...                                                 ...
# 1523                                                NaN
# 1524                                                NaN
# 1525                                                NaN
# 1526                                                NaN
# 1527                                                NaN
#
#                                                    발병기전  \
# 0                                                   NaN
# 1     99%는 양성선종으로 이 분비샘에서 자동으로 갑상선 호르몬이 과다분비되며 복합적으로...
# 2     # CCV의 직접 감염에 의하거나, 스트레스에의한 현성 발현 또는 오염된 분변을 통...
# 3     # CPV-2는 고양이 범백혈구 감소증 바이러스(FPV)나 다른 육식동물에 감염되는...
# 4     # CDV는 범장기친화성 바이러스이며 림프절, 상피세포 및 신경세포에도 친화성, s...
# ...                                                 ...
# 1523                                                NaN
# 1524                                                NaN
# 1525                                                NaN
# 1526                                                NaN
# 1527                                                NaN
#
#                                                 발병 및 역학  \
# 0     [후천성 갑상선기능저하증]\r# 개에서 원발성이 가장 흔함(증례의 95%이상을 차지...
# 1     #주로 고양이에 발생\r# 노령의 고양이에서 주로 발생함\r# 4-22살 된 고양이...
# 2     # 성견에서는 불현성 감염이나 경미한 임상증상을 보이나 자견에서는 녹황색에서 담적색...
# 3     # 발병장기\r -심혈관계: 심근염으로 급사(드뭄)\r -위장관계: 소장의 음와세포...
# 4     # 1-2일 동안 발열, 질병 초기 림프구 감소증, 말기에 면역기능 부전에 빠짐, ...
# ...                                                 ...
# 1523                                                NaN
# 1524                                                NaN
# 1525                                                NaN
# 1526                                                NaN
# 1527                                                NaN
#
#                                                    주요증상  \
# 0      | 거친 피모 , 곤두선 털 | 과각화증 , 두꺼운 피부 | 난산 | 무기력 , ...
# 1      | 1도 방실 심 차단 | 2도 방실 심 차단 | 각차단 , 좌각차단 , 우각차단...
# 2      | 구토 | 무기력 , 침울 , 졸림 , 생기없음 | 발열 , 고열 | 분변 냄새...
# 3      | 구강점막의궤양 , 수포 , 플라크(반) , 농포 , 미란 , 절창 | 구토 |...
# 4      | 각막의 궤양 , 미란 | 거리감각불능 , 거리감각 과대 및 과소 | 걷다 앞으...
# ...                                                 ...
# 1523  결막 , 공막의 발적 | 결막 , 공막의 충혈 | 급사 | 무기력 | 식욕부진 | ...
# 1524                                           목소리 변성 |
# 1525  뒷다리 위축 | 골반 및 회음부의 종창 | 골반 , 둔부 통증 | 골반위축 | 뒷다...
# 1526  골반 및 회음부의 종창 | 뒷다리 종창 | 뒷다리 파행 | 머리 , 얼굴 , 귀 ,...
# 1527  난산 | 배뇨곤란 | 복강내부 종괴 | 빈뇨 | 식욕부진 | 암컷의 불임증 | 외음...
#
#                                                      진단  \
# 0     [CBC, 혈액화학치, 뇨검사]\r# 고콜레스테롤혈증-갑상선기능저하증을 갖는 개의 ...
# 1          # 촉진을 하여 80-90%에서 가능하지만 촉진된다고 해서 항상 양성은 아님\r
# 2           혈청학적 진단, 바이러스 분리, 면역형광검사, 전자현미경, PCR(급성기)\r
# 3     이화학적 검사, 병력, 증상, 분변에서 바이러스 검출, ELISA, EM, IF, ...
# 4     # 이화학검사, 병력, 증상, 결막, 질, 혈구 도말후 봉입체 검사, FA, PCR...
# ...                                                 ...
# 1523                                                NaN
# 1524                                                NaN
# 1525                                                NaN
# 1526                                                NaN
# 1527                                                NaN
#
#                                                    감별진단  \
# 0     #피부병변은 갑상선기능저하증을 앓는 개에서 현저한 임상증상임\r# 탈모를 유발하는 ...
# 1                                                   NaN
# 2     # CPV-2\r# 살모넬라증, 대장균증 및 기타 세균성 장염\r# FIP\r# 위...
# 3     # 개 코로나바이러스 장염\r# 살모넬라증, 대장균증 및 기타 세균성 장염\r# 위...
# 4     # 켄넬코프(Kennel cough)- 호흡기 증상이 유사\r# 장염증상-개 파보바...
# ...                                                 ...
# 1523                                                NaN
# 1524                                                NaN
# 1525                                                NaN
# 1526                                                NaN
# 1527                                                NaN
#
#                                                    병리소견  \
# 0      [방사선소견]\r 골단형성장애, 골단골화의 지연, 짧은 척추체가 선천성 갑상선기능...
# 1     [임상병리소견]\r# 미세한 ALP와 ALT가 증가 \r# 혈청내 T4의 농도 상승...
# 2     [임상병리소견]\r  PCV증가, CPV와 달리 백혈구 감소가 관찰되지 않음\r [...
# 3      [임상병리소견]\r  림프구감소증(감염후 4-6일), 심한 경우 장 손상과 함께 ...
# 4     [ 임상병리소견 ]\r  감염초기에 림프구감소증, 후기 2차 세균감염으로 호중구증가...
# ...                                                 ...
# 1523                                                NaN
# 1524                                                NaN
# 1525                                                NaN
# 1526                                                NaN
# 1527                                                NaN
#
#                                                      치료  \
# 0     #식이요법-체중과 T4 농도가 정상으로 될 때까지 지방 섭취를 제한\r# 원발성 갑...
# 1     #치료는 질병의 양상, 나이, 생리적인 상태 등을 고려하여 치료법을 선택함\r[외과...
# 2     # 치료하지 않아도 회복되는 경우도 있으나 심할 경우 대증요법 외에 특별한 치료법 ...
# 3     # 구토가 있을 때 사료급여 제한시킬 것: 구토증상이 없어진 24시간 후(심한 경우...
# 4     # 기침 : 거담제, 기관지 확장제\r# 경련 : 뇌부종시 dexamethasone...
# ...                                                 ...
# 1523                                                NaN
# 1524                                                NaN
# 1525                                                NaN
# 1526                                                NaN
# 1527                                                NaN
#
#                                                      예방  \
# 0                              적절하고 꾸준한 치료가 병의 재발을 막음\r
# 1                                                   NaN
# 2                                     사독 또는 순화 CCV 백신\r
# 3     # 모체이행 항체지속: 6-20주\r# 이 기간은 개체에 따라 모체항체가가 떨어지기...
# 4     #야외동물과의 접촉 피할 것\r# 백신:\r  MLV-CD(Modified live...
# ...                                                 ...
# 1523                                                NaN
# 1524                                                NaN
# 1525                                                NaN
# 1526                                                NaN
# 1527                                                NaN
#
#                                                      예후  \
# 0     #부적절하게 고용량의 L-thyroxine을 계속 투여하면 의원성 \r  갑상선기능...
# 1        # 갑상선암 (Thyroid carcinomas)일 경우에는 예후가 좋지 않음 \r
# 2      자견에서 심한 감염을 제외하고는 일반적으로 예후가 좋고 며칠간만 치료하면 회복 가능\r
# 3     # 일반적으로 감염후 3-4일 동안 생존하면 빠르게 회복, 백혈구 감소증과 면역억압...
# 4     # 병원체의 종류와 숙주의 반응에 따라 예후가 아주 다양함\r# 점액화농성 삼출물 ...
# ...                                                 ...
# 1523                                                NaN
# 1524                                                NaN
# 1525                                                NaN
# 1526                                                NaN
# 1527                                                NaN
#
#                                              보호자에 대한 조언  \
# 0     # 환축은 평생동안 치료받아야함을 이해시킴\r# 때때로 피부병변이 치료 시작하고 한...
# 1                                                   NaN
# 2     # CCV는 백신후 면역력 획득이 좋으므로 백신이 매우 중요함\r# 치료후 10-1...
# 3     # 소독의 필요성을 설명, 표백제(5% sodium hypochlorite를 1:3...
# 4     # CD의 증상이 심하지 않더라도 폐사율이 50%정도임을 알릴 것 \r# 좋은 백신...
# ...                                                 ...
# 1523                                                NaN
# 1524                                                NaN
# 1525                                                NaN
# 1526                                                NaN
# 1527                                                NaN
#
#                                                      기타  \
# 0     # T4 - tetraiodothyronine, levothyroxine \r# T...
# 1      Tapazole : tyrosyl group의 thyroglobulin안의 iod...
# 2                                                   NaN
# 3                                                   NaN
# 4     # 면역억압으로 톡소플라즈마가 복합감염 될 수 있음\r# 켄널코프와도 병발 가능\r...
# ...                                                 ...
# 1523                                                NaN
# 1524                                                NaN
# 1525                                                NaN
# 1526                                                NaN
# 1527                                                NaN
#
#                                                    참고문헌
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3      \r1. 박남용 외, 수의병리학 각론, 전남대학교 출판부, 219, 2000\r2...
# 4     1. 박남용 외, 수의병리학 각론, 전남대학교 출판부, 151, 2000\r2. 박...
# ...                                                 ...
# 1523                                                NaN
# 1524                                                NaN
# 1525                                                NaN
# 1526                                                NaN
# 1527                                                NaN
#
# [1528 rows x 17 columns]

# %%
# 필요없는 열 삭제
petDisease = petDisease.loc[:,['질병명','축종','주요증상']]

# %%
petDisease
# Out:
#                                                     질병명      축종  \
# 0                              갑상선기능저하증(Hypothyroidism)  개, 고양이
# 1                            갑상선기능항진증 (Hyperthyroidism)  개, 고양이
# 2         코로나 바이러스 감염증, 개(Canine Coronavirus Infection)       개
# 3            파보바이러스 감염증, 개(Canine Parvoviral Infection)       개
# 4                     디스템퍼(Canine Distemper:CD), 개, 개홍역       개
# ...                                                 ...     ...
# 1523  데본 렉스 종 고양이에서 발생하는 비타민 K 의존성 다인성 응고 부전 (Vitami...     고양이
# 1524  개에서의 기관 내 삽관 후 발생하는 성대 마비 (Vocal cord paralysi...       개
# 1525  도베르만 핀셔에서의 폰 빌리브란트 이소성 osteochondrofibrosis (V...       개
# 1526               폰 빌리브란트 병 (Von willebrand's disease)  개, 고양이
# 1527  개와 고양이의 외음부와 질의 종양 (Vulval and vaginal neoplas...  개, 고양이
#
#                                                    주요증상
# 0      | 거친 피모 , 곤두선 털 | 과각화증 , 두꺼운 피부 | 난산 | 무기력 , ...
# 1      | 1도 방실 심 차단 | 2도 방실 심 차단 | 각차단 , 좌각차단 , 우각차단...
# 2      | 구토 | 무기력 , 침울 , 졸림 , 생기없음 | 발열 , 고열 | 분변 냄새...
# 3      | 구강점막의궤양 , 수포 , 플라크(반) , 농포 , 미란 , 절창 | 구토 |...
# 4      | 각막의 궤양 , 미란 | 거리감각불능 , 거리감각 과대 및 과소 | 걷다 앞으...
# ...                                                 ...
# 1523  결막 , 공막의 발적 | 결막 , 공막의 충혈 | 급사 | 무기력 | 식욕부진 | ...
# 1524                                           목소리 변성 |
# 1525  뒷다리 위축 | 골반 및 회음부의 종창 | 골반 , 둔부 통증 | 골반위축 | 뒷다...
# 1526  골반 및 회음부의 종창 | 뒷다리 종창 | 뒷다리 파행 | 머리 , 얼굴 , 귀 ,...
# 1527  난산 | 배뇨곤란 | 복강내부 종괴 | 빈뇨 | 식욕부진 | 암컷의 불임증 | 외음...
#
# [1528 rows x 3 columns]

# %%
petDisease['주요증상'][11]
# Out:
# ' 기침 |  기침시 객혈 | 다호흡 , 빠른호흡(빈호흡), 과호흡 | 무기력 , 침울 , 졸림 , 생기없음 | 발열 , 고열 | 비정상의 폐포음 , 흉강음 , 랏셀음 , 염발음 , 천명음 , 마찰음 | 수척 , 건강상태 불량 , 증체율 불량 |식욕부진 , 식욕감소 , 식욕절폐 , 젖을 안먹임 , 먹이 공급 중단 | 체중감소 | 호흡곤란 , 개구호흡 , 그르렁거림 , 가쁜호흡 | 호흡시 이상한 냄새 , 구강의 악취 | 흉부 , 흉곽 , 늑골 , 흉골의 통증 \r'

# %%
petDisease = petDisease.dropna(subset=['축종'])
petDisease = petDisease.dropna(subset=['주요증상'])
petDisease = petDisease.dropna(subset=['질병명'])

# %%
petDisease['주요증상'] = petDisease['주요증상'].str.replace(" ","")
petDisease
# Out:
#                                                     질병명      축종  \
# 0                              갑상선기능저하증(Hypothyroidism)  개, 고양이
# 1                            갑상선기능항진증 (Hyperthyroidism)  개, 고양이
# 2         코로나 바이러스 감염증, 개(Canine Coronavirus Infection)       개
# 3            파보바이러스 감염증, 개(Canine Parvoviral Infection)       개
# 4                     디스템퍼(Canine Distemper:CD), 개, 개홍역       개
# ...                                                 ...     ...
# 1523  데본 렉스 종 고양이에서 발생하는 비타민 K 의존성 다인성 응고 부전 (Vitami...     고양이
# 1524  개에서의 기관 내 삽관 후 발생하는 성대 마비 (Vocal cord paralysi...       개
# 1525  도베르만 핀셔에서의 폰 빌리브란트 이소성 osteochondrofibrosis (V...       개
# 1526               폰 빌리브란트 병 (Von willebrand's disease)  개, 고양이
# 1527  개와 고양이의 외음부와 질의 종양 (Vulval and vaginal neoplas...  개, 고양이
#
#                                                    주요증상
# 0     |거친피모,곤두선털|과각화증,두꺼운피부|난산|무기력,침울,졸림,생기없음|발육정지,체...
# 1     |1도방실심차단|2도방실심차단|각차단,좌각차단,우각차단,양각차단|거친피모,곤두선털|...
# 2     |구토|무기력,침울,졸림,생기없음|발열,고열|분변냄새의이상|설사,하리|식욕부진,식욕...
# 3     |구강점막의궤양,수포,플라크(반),농포,미란,절창|구토|기립불능,다우너|림프절종대,...
# 4     |각막의궤양,미란|거리감각불능,거리감각과대및과소|걷다앞으로넘어짐,목적없이배회|결막,...
# ...                                                 ...
# 1523  결막,공막의발적|결막,공막의충혈|급사|무기력|식욕부진|점상또는반상출혈|창백|출혈,응...
# 1524                                             목소리변성|
# 1525  뒷다리위축|골반및회음부의종창|골반,둔부통증|골반위축|뒷다리파행|출혈,응고부전|피부괴...
# 1526  골반및회음부의종창|뒷다리종창|뒷다리파행|머리,얼굴,귀,턱,코의종창|목부위종창|복강외...
# 1527  난산|배뇨곤란|복강내부종괴|빈뇨|식욕부진|암컷의불임증|외음부궤양,수포|외음부,음핵의...
#
# [1517 rows x 3 columns]

# %%
# !pip install konlpy
# !pip install jpype1
# !pip install pytagcloud
# !pip install pygame
# !pip install simplejson

import jpype
import konlpy

from konlpy.tag import Mecab
from nltk import FreqDist
from collections import Counter

import urllib
import random
import webbrowser

from konlpy.tag import Twitter
from lxml import html
import pytagcloud # requires Korean font support
import sys
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting konlpy
#   Downloading konlpy-0.6.0-py2.py3-none-any.whl (19.4 MB)
#      |████████████████████████████████| 19.4 MB 6.0 MB/s
# Requirement already satisfied: numpy>=1.6 in /usr/local/lib/python3.7/dist-packages (from konlpy) (1.21.6)
# Requirement already satisfied: lxml>=4.1.0 in /usr/local/lib/python3.7/dist-packages (from konlpy) (4.2.6)
# Collecting JPype1>=0.7.0
#   Downloading JPype1-1.4.0-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.whl (453 kB)
#      |████████████████████████████████| 453 kB 76.2 MB/s
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from JPype1>=0.7.0->konlpy) (4.1.1)
# Installing collected packages: JPype1, konlpy
# Successfully installed JPype1-1.4.0 konlpy-0.6.0
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: jpype1 in /usr/local/lib/python3.7/dist-packages (1.4.0)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from jpype1) (4.1.1)
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting pytagcloud
#   Downloading pytagcloud-0.3.5.tar.gz (754 kB)
#      |████████████████████████████████| 754 kB 7.4 MB/s
# Building wheels for collected packages: pytagcloud
#   Building wheel for pytagcloud (setup.py) ... done
#   Created wheel for pytagcloud: filename=pytagcloud-0.3.5-py3-none-any.whl size=759866 sha256=4ca579988560e395c2ad40579cfc090500eb847651bc408de88f45fbe2d7aa42
#   Stored in directory: /root/.cache/pip/wheels/fc/fd/aa/86956a295a7c9205bafd518ef4b6d489e51d2d476990c18238
# Successfully built pytagcloud
# Installing collected packages: pytagcloud
# Successfully installed pytagcloud-0.3.5
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting pygame
#   Downloading pygame-2.1.2-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (21.8 MB)
#      |████████████████████████████████| 21.8 MB 1.6 MB/s
# Installing collected packages: pygame
# Successfully installed pygame-2.1.2
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting simplejson
#   Downloading simplejson-3.17.6-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (130 kB)
#      |████████████████████████████████| 130 kB 7.3 MB/s
# Installing collected packages: simplejson
# Successfully installed simplejson-3.17.6
# pygame 2.1.2 (SDL 2.0.16, Python 3.7.13)
# Hello from the pygame community. https://www.pygame.org/contribute.html

# %%
from konlpy.tag import Twitter

twt = Twitter()

all_words = []

for n in range(len(petDisease)):
  text = petDisease['주요증상'].iloc[n]
  text = text.replace('|',',')
  text = text.replace('\r','')
  words = text.split(',')
  for word in words:
    if word not in all_words and len(word)>0:
        all_words.append(word)

print(len(all_words),all_words)
# Out:
# /usr/local/lib/python3.7/dist-packages/konlpy/tag/_okt.py:17: UserWarning: "Twitter" has changed to "Okt" since KoNLPy v0.4.5.
#   warn('"Twitter" has changed to "Okt" since KoNLPy v0.4.5.')
# 1661 ['거친피모', '곤두선털', '과각화증', '두꺼운피부', '난산', '무기력', '침울', '졸림', '생기없음', '발육정지', '체중증가없음', '성장지연', '배변량감소', '변비', '배변안됨', '비만', '체중과다', '과체중', '서맥', '느린심박동이나맥박', '식욕부진', '식욕감소', '식욕절폐', '젖을안먹임', '먹이공급중단', '저체온증', '낮은체온', '탈모', '무모증', '털이광택이없이덥수룩하거나지저분함', '피부부종', '피부인설', '비듬', '비늘', '피부', '털의건조', '1도방실심차단', '2도방실심차단', '각차단', '좌각차단', '우각차단', '양각차단', '걷다앞으로넘어짐', '목적없이배회', '구강점막의울혈', '홍반', '발적', '구토', '기침', '다뇨증', '다식증', '과도한식욕', '다음', '많이마심', '지나친갈증', '다호흡', '빠른호흡(빈호흡)', '과호흡', '떨림', '전율', '오한', '맥박강도증가', '목부위종창', '경부의종괴', '목소리변성', '발열', '고열', '발작', '실신', '경련', '간질발작', '허탈', '부정맥', '불규칙한심박및맥박', '분마율동', '분마성리듬', '분변냄새의이상', '비정상의폐포음', '흉강음', '랏셀음', '염발음', '천명음', '마찰음', '비정상적또는공격적행동', '습성이바뀜', '심방빈맥', '빈박', '설사', '하리', '수척', '건강상태불량', '증체율불량', '심방조기박동', '심실기외수축', '다발성혹은단발성', '심실이탈박동', '심실확장', '좌', '우혹은양쪽', '심음의감소', '심잡음', '약맥', '소맥', '운동실조', '협조불능', '절뚝거림', '넘어짐', '재채기', '전신허약', '부전마비', '마비', '지각과민', '예민함', '과다운동', '지루성피부', '털', '깃털', '지방변', '진전', '체중감소', '탈수', '폐포음감소', '호흡음이없음', '피하염발음', '피하기종', '혈뇨', '호흡곤란', '개구호흡', '그르렁거림', '가쁜호흡', '후두', '기관', '인두의종창', '종괴', '흥분', '헛소리', '광분', '점액변', '점액양분변', '혈변', '구강점막의궤양', '수포', '플라크(반)', '농포', '미란', '절창', '기립불능', '다우너', '림프절종대', '림프절병증', '종창', '복강외부압박에따른통증', '복강내부종괴', '복수', '산통', '점상또는반상출혈', '점액양비강분비물', '점막', '피부창백', '빈혈', '토혈증', '귀', '다리냉감', '혼수', '혼미', '화농성비강분비물', '황달', '각막의궤양', '거리감각불능', '거리감각과대및과소', '결막', '공막부종', '공막의발적', '공막의충혈', '혈관의이상', '과도한침흘림', '유연', '입에거품', '근육긴장저하', '눈물이적음', '안구건조증', '눈물흘림', '장액성분비물', '축축한눈', '눈의화농성분비물', '동공부동', '뒷다리경련', '근경련', '뒷다리반사이상(증가나감소)', '뒷다리양쪽부전마비', '등부위경련', '망막박리', '망막색소침착이상', '망막반사이상', '망막출혈', '망막혈관크기이상', '머리기울기', '머리', '얼굴', '목의경련', '목', '경부', '목구멍통증', '목의경직', '뻣뻣한목', '분변실금', '비정상적인자세', '빛에대한동공의비정상반응', '사지마비', '산동', '확장된동공', '선회운동', '시신경위축', '크기감소', '시신경출혈', '실명', '시력상실', '안검연축', '안구진탕', '안구불수의적운동', '앞다리경련', '간대성근경련', '앞다리반사이상(증가나감소)', '앞다리허약', '요실금', '유두부종', '시신경크기증가', '유산', '허약한새끼분만', '사산', '이급후증', '배변곤란', '인두의홍반', '타박상', '장액성', '수양성', '피부구진', '피부농포', '피부통증', '깃털이축축함', '피부의가피', '딱지', '피부의궤양', '찰과상', '피부의열상', '교상', '피부홍반', '염증', '후궁반장', '각막색소침착이상', '각막의부종', '혼탁', '각막혈관신생', '판누스', '결막부종', '눈부심', '수명', '눈의통증', '안통', '안검내번', '눈꺼풀이속으로말림', '안구함몰', '눈이움푹꺼짐', '제3안검탈출', '순막의돌출', '축동', '동공축소', '골반', '둔부통증', '뒷다리관절이완', '탈구', '뒷다리및골반부', '후지골반마찰음', '뒷다리통증', '뒷다리파행', '경직', '절름발이', '이동거부', '각막의종창', '결절', '간', '비장종대', '간종대', '구역질', '근긴장증', '근경직증', '꼬리', '단백뇨', '대안구증', '녹내장', '동공형태비정상또는홍채의결함', '뒷다리위축', '야윔', '뒷다리종창', '종괴(관절부/비관절부포함)', '뒷발', '발가락종창', '처짐', '턱', '코의종창', '고열종창', '백내장', '수정체혼탁', '유착', '복부팽만', '비출혈', '코피', '사시', '사팔뜨기', '상부기도의비정상호흡음', '코고는소리', '모세혈관재충만시간지연', '소리계속지르기', '소리가커짐', '신장종대촉진', '안검하수', '안구전방출혈', '"블랙아이"', '안구돌출', '안와', '안와주위', '안구종괴', '암컷의불임증', '저수태', '앞다리위축', '앞다리종창', '종괴(관절부/비관절부위포함)', '앞다리파행', '외음부', '질의악취냄새', '분비물', '질의화농성분비물', '요통', '허리통증', '유리체(초자체)혼탁또는침전물', '유착증', '적색뇨', '갈색뇨', '전방축농', '안구전방에지질이나섬유소축적', '전신파행', '출혈', '응고부전', '피부괴사', '가피', '괴저', '피부누관', '공동형성', '피부또는피하의종창', '피하지방조직층반사이상(증가나감소)', '항문', '회음부', '꼬리반사이상', '분변내잠혈', '호흡시이상한냄새', '구강의악취', '홍채의색소침착이상', '당뇨', '망막주름', '융기', '방향감각상실', '기억상실', '심전도전압감소', '앞다리지각감퇴', '무감각', '연하곤란', '연하장애', '운동기피', '쉽게지침', '음경', '포피', '고환', '음낭의종대', '음낭', '고환크기이상', '이식증', '이기증(이물섭취기호증)', '청색증', '피부나점막이푸름', '케톤뇨', '우유나뇨중에케톤체', '편측부전마비', '구강', '혀의종창', '구개열', '구순열', '비도비강내섭취물', '이빨의결손', '이빨수감소', '기침시객혈', '흉부', '흉곽', '늑골', '흉골의통증', '소양감', '가려움', '피부색소과잉침착', '피부가비쩍마름', '야윈피부', '피부색소침착감소', '백반증', '백피증', '가슴', '흉강타진시둔탁한부위', '골반및회음부의종창', '과호흡뒷다리', '뒷다리뼈노출', '복강외부종창', '앞다리뼈노출', '앞발', '피부의악취', '냄새', '피부의화농성분비물', '갈증이줄어듬', '갈증이없음', '급사', '돌연사', '배뇨곤란', '앞다리통증', '핍뇨', '무뇨증', '요정체', '혈색소뇨', '근색소뇨', '눈내부종괴종창', '외음부궤양', '열상', '구진', '음핵의종대', '피부플라크(반)', '혀의궤양', '궤양', '귀긁기', '귀의진드기', '응애또는기생충분비물', '귀의화농성', '점액양분비물', '귓밥이많음', '악취', '뒷발통증', '머리흔들기', '앞발통증', '피부균열', '열구', '피부반흔', '흉터', '머리박치기', '골반위축', '둔부위축', '등부위위축', '혀위축', '위축', '야윈흉곽', '다뇨', '신장', '요관촉진시통증', '연하빈도증가', '뒷다리만곡', '굽음', '고열비정상의폐포음', '앞다리만곡', '목의염발음', '얼굴뼈노출', '귀의통증', '저작곤란', '잘씹지못함', '3도방실심완전차단', '심방', '심방세동', '심실세동', '조동', '흉부종창', '흉골의종괴', '강직성경련', '테타니', '혀지 ...

# %%
for word in all_words:
  if word.find("통증")!=-1:
    print(word)
# Out:
# 복강외부압박에따른통증
# 목구멍통증
# 피부통증
# 눈의통증
# 둔부통증
# 뒷다리통증
# 허리통증
# 흉골의통증
# 앞다리통증
# 뒷발통증
# 앞발통증
# 요관촉진시통증
# 귀의통증
# 유방통증
# 기관의통증
# 구강통증
# 구강점막및혀의통증
# 통증
# 질의통증
# 전립선통증
# 유방통증유선
# 음낭통증
# 안구통증
# 외부적인복강압력에대한통증
# 급통증
# 외부복강압력에대한통증
# 복강외부압력에대한통증
# 동공통증
# 구강과혀의통증
# 회음부통증
# 제대통증
# 뒷발통증뒷발
# 음경통증
# 포피통증
# 고환통증
# 피부의통증
# 늑골흉골의통증
# 복강외부압력에의한통증
# 뒷다리통증뒷다리파행
# 흉골통증
# 등의통증
# 외부복압상의통증
# 외복압에의한통증
# 골반통증
# 바깥복부통증
# 식도경부의통증
# 복강외부압력에따른통증
# 파행통증
# 뒷발통증종괴
# 앞발통증종괴
# 복강외부의압박에따른통증
# 외부압박에의한통증
# 혀의통증
# 뒷발가락통증
# 발굽의통증
# 강외부압박에따른통증

# %%
symptomList = pd.Series(all_words)
symptomList.to_csv('symptomList.csv')
