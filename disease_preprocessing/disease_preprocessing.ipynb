# %% [markdown]
# <a href="https://colab.research.google.com/github/qowngus33/Open-Potal-preprocessing/blob/main/preprocessing2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %matplotlib inline

import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

import pandas as pd

# 데이터프레임을 읽어옴
petdisease = pd.read_csv('petDisease.csv',encoding='UTF-8')

# %%
petdisease
# Out:
#       Unnamed: 0                                                질병명      축종  \
# 0              0                           갑상선기능저하증(Hypothyroidism)  개, 고양이
# 1              1                         갑상선기능항진증 (Hyperthyroidism)  개, 고양이
# 2              2      코로나 바이러스 감염증, 개(Canine Coronavirus Infection)       개
# 3              3         파보바이러스 감염증, 개(Canine Parvoviral Infection)       개
# 4              4                  디스템퍼(Canine Distemper:CD), 개, 개홍역       개
# ...          ...                                                ...     ...
# 1510        1523  데본 렉스 종 고양이에서 발생하는 비타민 K 의존성 다인성 응고 부전 (Vitami...     고양이
# 1511        1524  개에서의 기관 내 삽관 후 발생하는 성대 마비 (Vocal cord paralysi...       개
# 1512        1525  도베르만 핀셔에서의 폰 빌리브란트 이소성 osteochondrofibrosis (V...       개
# 1513        1526               폰 빌리브란트 병 (Von willebrand's disease)  개, 고양이
# 1514        1527  개와 고양이의 외음부와 질의 종양 (Vulval and vaginal neoplas...  개, 고양이
#
# ...

# %%
for i in range(len(petdisease)):
  tempStr = petdisease['주요증상'][i]
  if tempStr[0] == ' ' or tempStr[0] == ',':
    tempStr = tempStr[1:]
  if tempStr[0] == ' ' or tempStr[0] == ',':
    tempStr = tempStr[1:]
  if tempStr[0] == ' ' or tempStr[0] == ',':
    tempStr = tempStr[1:]
  if tempStr[0] == ' ' or tempStr[0] == ',':
    tempStr = tempStr[1:]
  petdisease['주요증상'][i] = tempStr
  print(tempStr)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # This is added back by InteractiveShellApp.init_path()
# 거친 피모 , 곤두선 털 , 과각화증 , 두꺼운 피부 , 난산 , 무기력 , 침울 , 졸림 , 생기없음 , 발육정지 , 체중증가없음 , 성장지연 , 배변량 감소 , 변비 , 배변 안됨 , 비만 , 체중과다 , 과체중 , 서맥 , 느린 심박동이나 맥박 , 식욕부진 , 식욕감소 , 식욕절폐 , 젖을 안먹임 , 먹이 공급 중단 , 저체온증 , 낮은체온 , 탈모 , 무모증 , 털이 광택이 없이 덥수룩 하거나 지저분함 , 피부 부종 , 피부 인설 , 비듬 , 비늘 , 피부 , 털의 건조 ,
# ...

# %%
for i in range(len(petdisease)):
  tempStr = petdisease['주요증상'][i]
  if tempStr[len(tempStr)-1] == ' ' or tempStr[len(tempStr)-1] == ',':
    tempStr = tempStr[0:len(tempStr)-1]
  if tempStr[len(tempStr)-1] == ' ' or tempStr[len(tempStr)-1] == ',':
    tempStr = tempStr[0:len(tempStr)-1]
  if tempStr[len(tempStr)-1] == ' ' or tempStr[len(tempStr)-1] == ',':
    tempStr = tempStr[0:len(tempStr)-1]
  if tempStr[len(tempStr)-1] == ' ' or tempStr[len(tempStr)-1] == ',':
    tempStr = tempStr[0:len(tempStr)-1]
  petdisease['주요증상'][i] = tempStr
  print(tempStr)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # This is added back by InteractiveShellApp.init_path()
# 거친 피모 , 곤두선 털 , 과각화증 , 두꺼운 피부 , 난산 , 무기력 , 침울 , 졸림 , 생기없음 , 발육정지 , 체중증가없음 , 성장지연 , 배변량 감소 , 변비 , 배변 안됨 , 비만 , 체중과다 , 과체중 , 서맥 , 느린 심박동이나 맥박 , 식욕부진 , 식욕감소 , 식욕절폐 , 젖을 안먹임 , 먹이 공급 중단 , 저체온증 , 낮은체온 , 탈모 , 무모증 , 털이 광택이 없이 덥수룩 하거나 지저분함 , 피부 부종 , 피부 인설 , 비듬 , 비늘 , 피부 , 털의 건조
# ...

# %%
petdisease['주요증상'][0][0:len(petdisease['주요증상'][0])]
# Out:
# '거친 피모 , 곤두선 털 , 과각화증 , 두꺼운 피부 , 난산 , 무기력 , 침울 , 졸림 , 생기없음 , 발육정지 , 체중증가없음 , 성장지연 , 배변량 감소 , 변비 , 배변 안됨 , 비만 , 체중과다 , 과체중 , 서맥 , 느린 심박동이나 맥박 , 식욕부진 , 식욕감소 , 식욕절폐 , 젖을 안먹임 , 먹이 공급 중단 , 저체온증 , 낮은체온 , 탈모 , 무모증 , 털이 광택이 없이 덥수룩 하거나 지저분함 , 피부 부종 , 피부 인설 , 비듬 , 비늘 , 피부 , 털의 건조'

# %%
petdisease['주요증상'] = petdisease['주요증상'].str.replace("  ,  ",", ")
petdisease['주요증상'] = petdisease['주요증상'].str.replace(" ,  ",", ")
petdisease['주요증상'] = petdisease['주요증상'].str.replace(",  ",", ")
petdisease['주요증상'] = petdisease['주요증상'].str.replace("  , ",", ")
petdisease['주요증상'] = petdisease['주요증상'].str.replace("  ,",", ")
petdisease['주요증상'] = petdisease['주요증상'].str.replace(" , ",", ")
petdisease['주요증상'] = petdisease['주요증상'].str.replace(", ",", ")
petdisease['주요증상'] = petdisease['주요증상'].str.replace(",,",", ")
petdisease['주요증상'] = petdisease['주요증상'].str.replace(",,",", ")
petdisease['주요증상'] = petdisease['주요증상'].str.replace(",,",", ")
petdisease['주요증상'] = petdisease['주요증상'].str.replace(",,",", ")
petdisease['주요증상'] = petdisease['주요증상'].str.replace(", ,",", ")
petdisease['주요증상'] = petdisease['주요증상'].str.replace(", ,",", ")
petdisease['주요증상'] = petdisease['주요증상'].str.replace(", ,",", ")
petdisease['주요증상'] = petdisease['주요증상'].str.replace(", ,",", ")
petdisease['주요증상'] = petdisease['주요증상'].str.replace(",  ,",",")
petdisease['주요증상'] = petdisease['주요증상'].str.replace(",  ,",",")
petdisease['주요증상'] = petdisease['주요증상'].str.replace(",  ,",",")
petdisease['주요증상'] = petdisease['주요증상'].str.replace(",   ,",",")
petdisease['주요증상'] = petdisease['주요증상'].str.replace(",   ,",",")
petdisease['주요증상'] = petdisease['주요증상'].str.replace(",    ,",",")

petdisease['주요증상']
# Out:
# 0       거친 피모, 곤두선 털, 과각화증, 두꺼운 피부, 난산, 무기력, 침울, 졸림, 생...
# 1       도 방실 심 차단, 도 방실 심 차단, 각차단, 좌각차단, 우각차단, 양각차단, 거...
# 2       구토, 무기력, 침울, 졸림, 생기없음, 발열, 고열, 분변 냄새의 이상, 설사, ...
# 3       구강점막의궤양, 수포, 플라크,반,  농포, 미란, 절창, 구토, 기립불능 ,다우너...
# 4       각막의 궤양, 미란, 거리감각불능, 거리감각 과대 및 과소, 걷다 앞으로 넘어짐, ...
#                               ...
# 1510    결막, 공막의 발적, 결막, 공막의 충혈, 급사, 무기력, 식욕부진, 점상 또는 반...
# 1511                                               목소리 변성
# 1512    뒷다리 위축, 골반 및 회음부의 종창, 골반, 둔부 통증, 골반위축, 뒷다리 파행 ...
# 1513    골반 및 회음부의 종창, 뒷다리 종창, 뒷다리 파행, 머리, 얼굴, 귀, 턱, 코의...
# 1514    난산, 배뇨곤란, 복강내부 종괴, 빈뇨, 식욕부진, 암컷의 불임증, 외음부 궤양, ...
# Name: 주요증상, Length: 1515, dtype: object

# %%
petdisease.drop(['Unnamed: 0'], axis = 1, inplace = True)
petdisease
# Out:
#                                                     질병명      축종  \
# 0                              갑상선기능저하증(Hypothyroidism)  개, 고양이
# 1                            갑상선기능항진증 (Hyperthyroidism)  개, 고양이
# 2         코로나 바이러스 감염증, 개(Canine Coronavirus Infection)       개
# 3            파보바이러스 감염증, 개(Canine Parvoviral Infection)       개
# 4                     디스템퍼(Canine Distemper:CD), 개, 개홍역       개
# ...                                                 ...     ...
# 1510  데본 렉스 종 고양이에서 발생하는 비타민 K 의존성 다인성 응고 부전 (Vitami...     고양이
# 1511  개에서의 기관 내 삽관 후 발생하는 성대 마비 (Vocal cord paralysi...       개
# 1512  도베르만 핀셔에서의 폰 빌리브란트 이소성 osteochondrofibrosis (V...       개
# 1513               폰 빌리브란트 병 (Von willebrand's disease)  개, 고양이
# 1514  개와 고양이의 외음부와 질의 종양 (Vulval and vaginal neoplas...  개, 고양이
#
#                                                      정의  \
# 0     갑상선에서 T3, T4의 부적절한 생산, 분비로 세포대사활성 및 행동기능의 저하가 ...
# 1                      T3와 T4의 분비와 과도한 생산물에 결과로 나타난 질병
# ...

# %%
petdisease.to_csv("petDisease2.csv")
